# %%
# Numpy --> for numarical data (arrays) --> 2005

# Pandas  <------ numpy ---> 2007

# file exentations : csv, excel, json,sheet....

# %%
pandas --> 2 datastructurs

1) Series
2) DataFrame

# %%
1) Series --> a single column in a table

2) DataFrame ---> combination of multiple Series

# %%
# !pip install pandas
# Out:
# ...
# DEPRECATION: textract 1.6.5 has a non-standard dependency specifier extract-msg<=0.29.*. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of textract or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
#
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
lst = ["hlo", "meash", "kriss", "moris", "clam"]

# %%
username = pd.Series(lst)
username
# Out:
# 0      hlo
# 1    meash
# 2    kriss
# 3    moris
# 4     clam
# dtype: object

# %%
type(username)
# Out:
# pandas.core.series.Series

# %%
username[1]
# Out:
# 'meash'

# %%
username = pd.Series(lst, index = ['a', 'b', 'c', 'd', 'e'])
username
# Out:
# a      hlo
# b    meash
# c    kriss
# d    moris
# e     clam
# dtype: object

# %%
username['e']
# Out:
# 'clam'

# %%
# DataFrame

df = pd.DataFrame(
    {
        "Name" : ["kriss", "moris", "surah", "ganesh", "no"],
        "Age" : [20, 21, 21, 18, 32],
        "Phone_Number" : [8234683634, 82364324, 928634863, 928364982, 7293469383]
    }
)

df
# Out:
#      Name  Age  Phone_Number
# 0   kriss   20    8234683634
# 1   moris   21      82364324
# 2   surah   21     928634863
# 3  ganesh   18     928364982
# 4      no   32    7293469383

# %%
type(df["Age"])
# Out:
# pandas.core.series.Series

# %%
df["Age"]
# Out:
# 0    20
# 1    21
# 2    21
# 3    18
# 4    32
# Name: Age, dtype: int64

# %%
# iloc
# loc

# %%
df
# Out:
#      Name  Age  Phone_Number
# 0   kriss   20    8234683634
# 1   moris   21      82364324
# 2   surah   21     928634863
# 3  ganesh   18     928364982
# 4      no   32    7293469383

# %%
#get single row's data

dataframe.loc[indxnumber_of_row]

df.loc[1]
# Out:
# Name               moris
# Age                   21
# Phone_Number    82364324
# Name: 1, dtype: object

# %%
# loading data:::::::

# %%
data = pd.read_csv("World Population by country 2024.csv")

# %%
data
# Out:
#               Country  Population 2024  Population 2023 Area (km2)  \
# 0               India       1441719852       1428627663         3M
# 1               China       1425178782       1425671352       9.4M
# 2       United States        341814420        339996563       9.1M
# 3           Indonesia        279798049        277534122       1.9M
# 4            Pakistan        245209815        240485658     770.9K
# ..                ...              ...              ...        ...
# 229        Montserrat             4372             4386        102
# 230  Falkland Islands             3803             3791      12.2K
# 231              Niue             1935             1935        261
# 232           Tokelau             1915             1893         10
# 233      Vatican City              526              518        < 1
#
#      Density (/km2)  Growth Rate  World %  World Rank
# 0            485.00       0.0092   0.1801           1
# ...

# %%
# head() ---> it return top 5 rows from our dataframe

# %%
data.head()
# Out:
#          Country  Population 2024  Population 2023 Area (km2)  Density (/km2)  \
# 0          India       1441719852       1428627663         3M           485.0
# 1          China       1425178782       1425671352       9.4M           151.0
# 2  United States        341814420        339996563       9.1M            37.0
# 3      Indonesia        279798049        277534122       1.9M           149.0
# 4       Pakistan        245209815        240485658     770.9K           318.0
#
#    Growth Rate  World %  World Rank
# 0       0.0092   0.1801           1
# 1      -0.0003   0.1780           2
# 2       0.0053   0.0427           3
# 3       0.0082   0.0350           4
# 4       0.0196   0.0306           5

# %%
data.head(10)
# Out:
#          Country  Population 2024  Population 2023 Area (km2)  Density (/km2)  \
# 0          India       1441719852       1428627663         3M           485.0
# 1          China       1425178782       1425671352       9.4M           151.0
# 2  United States        341814420        339996563       9.1M            37.0
# 3      Indonesia        279798049        277534122       1.9M           149.0
# 4       Pakistan        245209815        240485658     770.9K           318.0
# 5        Nigeria        229152217        223804632     910.8K           252.0
# 6         Brazil        217637297        216422446       8.4M            26.0
# 7     Bangladesh        174701211        172954319     130.2K          1342.0
# 8         Russia        143957079        144444359      16.4M             9.0
# 9       Ethiopia        129719719        126527060       1.1M           115.0
#
#    Growth Rate  World %  World Rank
# 0       0.0092   0.1801           1
# 1      -0.0003   0.1780           2
# ...

# %%
# tail()  ---> it return last 5 rows from dataset

# %%
data.tail()
# Out:
#               Country  Population 2024  Population 2023 Area (km2)  \
# 229        Montserrat             4372             4386        102
# 230  Falkland Islands             3803             3791      12.2K
# 231              Niue             1935             1935        261
# 232           Tokelau             1915             1893         10
# 233      Vatican City              526              518        < 1
#
#      Density (/km2)  Growth Rate  World %  World Rank
# 229           43.00      -0.0032      NaN         230
# 230            0.31       0.0032      NaN         231
# 231            7.00       0.0000      NaN         232
# 232          192.00       0.0116      NaN         233
# 233         1195.00       0.0154      NaN         234

# %%
data.tail(10)
# Out:
#                        Country  Population 2024  Population 2023 Area (km2)  \
# 224                      Nauru            12884            12780         20
# 225                     Tuvalu            11478            11396         30
# 226          Wallis and Futuna            11439            11502        274
# 227           Saint Barthelemy            11019            10994         25
# 228  Saint Pierre and Miquelon             5815             5840        242
# 229                 Montserrat             4372             4386        102
# 230           Falkland Islands             3803             3791      12.2K
# 231                       Niue             1935             1935        261
# 232                    Tokelau             1915             1893         10
# 233               Vatican City              526              518        < 1
#
#      Density (/km2)  Growth Rate  World %  World Rank
# 224          644.00       0.0081      0.0         225
# ...

# %%
head() --> top 5 rows
tail() ---> last 5 rows

sample() --> it return a single row randomly

# %%
data.sample()
# Out:
#   Country  Population 2024  Population 2023 Area (km2)  Density (/km2)  \
# 8  Russia        143957079        144444359      16.4M             9.0
#
#    Growth Rate  World %  World Rank
# 8      -0.0034    0.018           9

# %%
data.sample(5)
# Out:
#               Country  Population 2024  Population 2023 Area (km2)  \
# 114           Denmark          5939695          5910913        40K
# 69          Guatemala         18358430         18092026     107.2K
# 230  Falkland Islands             3803             3791      12.2K
# 68            Ecuador         18377367         18190484     248.4K
# 144           Namibia          2645805          2604172     823.3K
#
#      Density (/km2)  Growth Rate  World %  World Rank
# 114          148.00       0.0049   0.0007         115
# 69           171.00       0.0147   0.0023          70
# 230            0.31       0.0032      NaN         231
# 68            74.00       0.0103   0.0023          69
# 144            3.00       0.0160   0.0003         145

# %%
head() --> top 5 rows
tail() ---> last 5 rows

sample() --> it return a single row randomly

shape ----> return how manay number of rows and columns

# %%
data.shape
# Out:
# (234, 8)

# %%
head() --> top 5 rows
tail() ---> last 5 rows

sample() --> it return a single row randomly

shape ----> return how manay number of rows and columns

info()  ----> return information about our dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Country          234 non-null    object
#  1   Population 2024  234 non-null    int64
#  2   Population 2023  234 non-null    int64
#  3   Area (km2)       234 non-null    object
#  4   Density (/km2)   234 non-null    float64
#  5   Growth Rate      234 non-null    float64
#  6   World %          228 non-null    float64
#  7   World Rank       234 non-null    int64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 14.8+ KB

# %%
data.head(4)
# Out:
#          Country  Population 2024  Population 2023 Area (km2)  Density (/km2)  \
# 0          India       1441719852       1428627663         3M           485.0
# 1          China       1425178782       1425671352       9.4M           151.0
# 2  United States        341814420        339996563       9.1M            37.0
# 3      Indonesia        279798049        277534122       1.9M           149.0
#
#    Growth Rate  World %  World Rank
# 0       0.0092   0.1801           1
# 1      -0.0003   0.1780           2
# 2       0.0053   0.0427           3
# 3       0.0082   0.0350           4

# %%
head() --> top 5 rows
tail() ---> last 5 rows

sample() --> it return a single row randomly

shape ----> return how manay number of rows and columns

info()  ----> return information about our dataset

describle() ---> it return maximum information about only numarical columns.

# %%
data.describe()
# Out:
#        Population 2024  Population 2023  Density (/km2)  Growth Rate  \
# count     2.340000e+02     2.340000e+02      234.000000   234.000000
# mean      3.468862e+07     3.437442e+07      453.788248     0.009200
# std       1.380750e+08     1.373864e+08     1990.163274     0.011371
# min       5.260000e+02     5.180000e+02        0.140000    -0.030900
# 25%       4.264565e+05     4.225982e+05       39.500000     0.001925
# 50%       5.626359e+06     5.643895e+06       98.500000     0.007950
# 75%       2.392272e+07     2.324537e+07      248.250000     0.015675
# max       1.441720e+09     1.428628e+09    21674.000000     0.048300
#
#           World %  World Rank
# count  228.000000  234.000000
# mean     0.004446  117.500000
# std      0.017459   67.694165
# min      0.000000    1.000000
# 25%      0.000100   59.250000
# 50%      0.000750  117.500000
# 75%      0.003000  175.750000
# max      0.180100  234.000000

# %%
# how to exact data from dataset

# %%
# dataframe.iloc[rows, columns]

# %%
data.head()
# Out:
#          Country  Population 2024  Population 2023 Area (km2)  Density (/km2)  \
# 0          India       1441719852       1428627663         3M           485.0
# 1          China       1425178782       1425671352       9.4M           151.0
# 2  United States        341814420        339996563       9.1M            37.0
# 3      Indonesia        279798049        277534122       1.9M           149.0
# 4       Pakistan        245209815        240485658     770.9K           318.0
#
#    Growth Rate  World %  World Rank
# 0       0.0092   0.1801           1
# 1      -0.0003   0.1780           2
# 2       0.0053   0.0427           3
# 3       0.0082   0.0350           4
# 4       0.0196   0.0306           5

# %%
data.loc[1]
# Out:
# Country                 China
# Population 2024    1425178782
# Population 2023    1425671352
# Area (km2)               9.4M
# Density (/km2)          151.0
# Growth Rate           -0.0003
# World %                 0.178
# World Rank                  2
# Name: 1, dtype: object

# %%
data.head()
# Out:
#          Country  Population 2024  Population 2023 Area (km2)  Density (/km2)  \
# 0          India       1441719852       1428627663         3M           485.0
# 1          China       1425178782       1425671352       9.4M           151.0
# 2  United States        341814420        339996563       9.1M            37.0
# 3      Indonesia        279798049        277534122       1.9M           149.0
# 4       Pakistan        245209815        240485658     770.9K           318.0
#
#    Growth Rate  World %  World Rank
# 0       0.0092   0.1801           1
# 1      -0.0003   0.1780           2
# 2       0.0053   0.0427           3
# 3       0.0082   0.0350           4
# 4       0.0196   0.0306           5

# %%
# dataframe.iloc[rows, columns]

data.iloc[[1, 4, 200], :]
# Out:
#                  Country  Population 2024  Population 2023 Area (km2)  \
# 1                  China       1425178782       1425671352       9.4M
# 4               Pakistan        245209815        240485658     770.9K
# 200  Antigua and Barbuda            94816            94298        440
#
#      Density (/km2)  Growth Rate  World %  World Rank
# 1             151.0      -0.0003   0.1780           2
# 4             318.0       0.0196   0.0306           5
# 200           215.0       0.0055   0.0000         201

# %%
data.iloc[[1, 4, 200], [0, 1, 7]]
# Out:
#                  Country  Population 2024  World Rank
# 1                  China       1425178782           2
# 4               Pakistan        245209815           5
# 200  Antigua and Barbuda            94816         201

# %%
data.head()
# Out:
#          Country  Population 2024  Population 2023 Area (km2)  Density (/km2)  \
# 0          India       1441719852       1428627663         3M           485.0
# 1          China       1425178782       1425671352       9.4M           151.0
# 2  United States        341814420        339996563       9.1M            37.0
# 3      Indonesia        279798049        277534122       1.9M           149.0
# 4       Pakistan        245209815        240485658     770.9K           318.0
#
#    Growth Rate  World %  World Rank
# 0       0.0092   0.1801           1
# 1      -0.0003   0.1780           2
# 2       0.0053   0.0427           3
# 3       0.0082   0.0350           4
# 4       0.0196   0.0306           5

# %%
# data.iloc[2, 2]

# %%
data.iloc[ : , 0 : 3]
# Out:
#               Country  Population 2024  Population 2023
# 0               India       1441719852       1428627663
# 1               China       1425178782       1425671352
# 2       United States        341814420        339996563
# 3           Indonesia        279798049        277534122
# 4            Pakistan        245209815        240485658
# ..                ...              ...              ...
# 229        Montserrat             4372             4386
# 230  Falkland Islands             3803             3791
# 231              Niue             1935             1935
# 232           Tokelau             1915             1893
# 233      Vatican City              526              518
#
# [234 rows x 3 columns]
